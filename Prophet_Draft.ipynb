# %% [markdown]
# <a href="https://colab.research.google.com/github/moonbeam87/Stonks/blob/master/Prophet_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Intro To Prophet with Quandl to forecast stock Prices - Does not Work as Intended

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
# !pip install Quandl
import quandl

# %%
import numpy as np
from fbprophet import Prophet

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = 'NxTUTAQswbKs5ybBbwfK'
df = quandl.get('WIKI/AAPL')

# %%
print(df.shape[0], 'rows', 'AND', df.shape[1], 'columns')
df.head()
# Out:
# 9400 rows AND 12 columns
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9400 entries, 1980-12-12 to 2018-03-27
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         9400 non-null   float64
#  1   High         9400 non-null   float64
#  2   Low          9400 non-null   float64
#  3   Close        9400 non-null   float64
#  4   Volume       9400 non-null   float64
#  5   Ex-Dividend  9400 non-null   float64
#  6   Split Ratio  9400 non-null   float64
#  7   Adj. Open    9400 non-null   float64
#  8   Adj. High    9400 non-null   float64
#  9   Adj. Low     9400 non-null   float64
#  10  Adj. Close   9400 non-null   float64
#  11  Adj. Volume  9400 non-null   float64
# dtypes: float64(12)
# memory usage: 954.7 KB

# %%
df.drop(columns=['Open', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio', 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'])
# Out:
#               High
# Date
# 1980-12-12   28.87
# 1980-12-15   27.38
# 1980-12-16   25.37
# 1980-12-17   26.00
# 1980-12-18   26.75
# ...            ...
# 2018-03-21  175.09
# 2018-03-22  172.68
# 2018-03-23  169.92
# 2018-03-26  173.10
# 2018-03-27  175.15
#
# [9400 rows x 1 columns]

# %%
m = Prophet()
m.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1ab3c9387252> in <module>()
#       1 m = Prophet()
# ----> 2 m.fit(df)
#
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1080         if ('ds' not in df) or ('y' not in df):
#    1081             raise ValueError(
# -> 1082                 'Dataframe must have columns "ds" and "y" with the dates and '
#    1083                 'values respectively.'
#    1084             )
#
# ValueError: Dataframe must have columns "ds" and "y" with the dates and values respectively.

# %%
df.rename("Date": "ds", "High": "y")
# Out:
#   File "<ipython-input-11-f0051824c660>", line 1
#     df.rename("Date": "ds", "High": "y")
#                     ^
# SyntaxError: invalid syntax

# %%
df.rename(columns={"Date": "ds", "High": "y"})
# Out:
#               Open       y     Low    Close      Volume  Ex-Dividend  \
# Date
# 1980-12-12   28.75   28.87   28.75   28.750   2093900.0          0.0
# 1980-12-15   27.38   27.38   27.25   27.250    785200.0          0.0
# 1980-12-16   25.37   25.37   25.25   25.250    472000.0          0.0
# 1980-12-17   25.87   26.00   25.87   25.870    385900.0          0.0
# 1980-12-18   26.63   26.75   26.63   26.630    327900.0          0.0
# ...            ...     ...     ...      ...         ...          ...
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# ...

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 2 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 3 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 4 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1   0.402563   0.402563  0.400652    0.400652   43971200.0
# 2   0.373010   0.373010  0.371246    0.371246   26432000.0
# 3   0.380362   0.382273  0.380362    0.380362   21610400.0
# 4   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
df.rename(columns={"Date": "ds", "High": "y"})
# Out:
#              ds    Open       y     Low    Close      Volume  Ex-Dividend  \
# 0    1980-12-12   28.75   28.87   28.75   28.750   2093900.0          0.0
# 1    1980-12-15   27.38   27.38   27.25   27.250    785200.0          0.0
# 2    1980-12-16   25.37   25.37   25.25   25.250    472000.0          0.0
# 3    1980-12-17   25.87   26.00   25.87   25.870    385900.0          0.0
# 4    1980-12-18   26.63   26.75   26.63   26.630    327900.0          0.0
# ...         ...     ...     ...     ...      ...         ...          ...
# 9395 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 9396 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 9397 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 9398 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 9399 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#       Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  Adj. Volume
# ...

# %%
df.drop(columns=['Open', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio', 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'])
# Out:
#            Date    High
# 0    1980-12-12   28.87
# 1    1980-12-15   27.38
# 2    1980-12-16   25.37
# 3    1980-12-17   26.00
# 4    1980-12-18   26.75
# ...         ...     ...
# 9395 2018-03-21  175.09
# 9396 2018-03-22  172.68
# 9397 2018-03-23  169.92
# 9398 2018-03-26  173.10
# 9399 2018-03-27  175.15
#
# [9400 rows x 2 columns]

# %%
df = df.drop(columns=['Open', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio', 'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'])

# %%
df.head()
# Out:
#         Date   High
# 0 1980-12-12  28.87
# 1 1980-12-15  27.38
# 2 1980-12-16  25.37
# 3 1980-12-17  26.00
# 4 1980-12-18  26.75

# %%
df =df.rename(columns={"Date": "ds", "High": "y"})

# %%
df.head()
# Out:
#           ds      y
# 0 1980-12-12  28.87
# 1 1980-12-15  27.38
# 2 1980-12-16  25.37
# 3 1980-12-17  26.00
# 4 1980-12-18  26.75

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 9760 2019-03-23
# 9761 2019-03-24
# 9762 2019-03-25
# 9763 2019-03-26
# 9764 2019-03-27

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 9760 2019-03-23  68.024995  -21.560268  154.414401
# 9761 2019-03-24  67.976205  -22.875907  159.077529
# 9762 2019-03-25  63.963991  -30.430303  145.836435
# 9763 2019-03-26  63.639053  -26.026528  151.590411
# 9764 2019-03-27  63.504528  -27.679724  158.553898

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
fig = df.plot('y')

# %%
fig = df.plot('DS', 'y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-c7e9d1bf867c> in <module>()
# ----> 1 fig = df.plot('DS', 'y')
#
# ...

# %%
fig = df.plot('DS')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-041a04198026> in <module>()
# ----> 1 fig = df.plot('DS')
#
# ...

# %%
df.head()
# Out:
#           ds      y
# 0 1980-12-12  28.87
# 1 1980-12-15  27.38
# 2 1980-12-16  25.37
# 3 1980-12-17  26.00
# 4 1980-12-18  26.75

# %%
fig = df.plot('ds', 'y')

# %%
pip freeze
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# asgiref==3.2.7
# astor==0.8.1
# astropy==4.0.1.post1
# astunparse==1.6.3
# atari-py==0.2.6
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.1.0
# beautifulsoup4==4.6.3
# bleach==3.1.4
# blis==0.4.1
# bokeh==1.4.0
# boto3==1.12.38
# botocore==1.15.38
# Bottleneck==1.3.2
# branca==0.4.0
# bs4==0.0.1
# CacheControl==0.12.6
# cachetools==3.1.1
# catalogue==1.0.0
# certifi==2020.4.5.1
# cffi==1.14.0
# chainer==6.5.0
# chardet==3.0.4
# click==7.1.1
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.4.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cvxopt==1.2.4
# cvxpy==1.0.29
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.16
# daft==0.0.4
# dask==2.12.0
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.2
# defusedxml==0.6.0
# descartes==1.1.0
# ...

# %%
pip freeze -r
# Out:
# Usage:
#   pip3 freeze [options]
#
# -r option requires 1 argument

# %%
# !pip freeze > requirements.txt

# %%
# !cat requirements.txt
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# asgiref==3.2.7
# astor==0.8.1
# astropy==4.0.1.post1
# astunparse==1.6.3
# atari-py==0.2.6
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.1.0
# beautifulsoup4==4.6.3
# bleach==3.1.4
# blis==0.4.1
# bokeh==1.4.0
# boto3==1.12.38
# botocore==1.15.38
# Bottleneck==1.3.2
# branca==0.4.0
# bs4==0.0.1
# CacheControl==0.12.6
# cachetools==3.1.1
# catalogue==1.0.0
# certifi==2020.4.5.1
# cffi==1.14.0
# chainer==6.5.0
# chardet==3.0.4
# click==7.1.1
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.4.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cvxopt==1.2.4
# cvxpy==1.0.29
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.16
# daft==0.0.4
# dask==2.12.0
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.2
# defusedxml==0.6.0
# descartes==1.1.0
# ...

# %%
conda list -e > requirements.txt
# Out:
#   File "<ipython-input-5-251721696bfc>", line 1
#     conda list -e > requirements.txt
#              ^
# SyntaxError: invalid syntax

# %%
conda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d5ec2b366402> in <module>()
# ----> 1 conda
#
# NameError: name 'conda' is not defined

# %%
# !conda list -e > requirements.txt
# Out:
# /bin/bash: conda: command not found
